# %% [markdown]
# # MFCC PCA 실험

# %%
import pandas as pd
train_merge_pca = pd.read_csv('iot20d_reshaped_train_sample_merge.csv', index_col=None)
test_merge_pca = pd.read_csv('iot20d_reshaped_test_sample_merge.csv', index_col=None)

# %%
train_merge_pca
# Out:
#        Unnamed: 0          0          1          2          3          4  \
# 0               0 -33.710038  -6.334452 -27.143144  -0.606679 -11.370514
# 1               1 -40.375017  14.212651   1.763182  12.016703 -24.316610
# 2               2 -16.618506  13.368126  -4.060041   6.187063 -10.548125
# 3               3 -45.711610  10.236180   4.542680  11.547588 -24.644597
# 4               4 -92.399702 -25.770358 -21.386170  29.173253  -8.811529
# ...           ...        ...        ...        ...        ...        ...
# 89995       89995   3.489452  21.259421 -22.061928   6.216940  27.196671
# 89996       89996 -15.538074  26.465661 -10.533717  21.023354  -0.615558
# 89997       89997  -8.765533  11.772582 -15.241978  -0.311987  48.621343
# 89998       89998 -20.447929  25.419256  -4.054054  25.962007   9.082178
# 89999       89999   7.688982  36.157822 -10.196075   3.153587  31.153437
#
#                5          6          7          8          9         10  \
# 0       2.695571  -4.664715  -2.641940   6.632191  -6.338020   1.612597
# 1      37.053350  -6.720660 -14.689805   8.472120   5.485937  -7.179709
# 2      33.493583   8.215179   6.972005  28.188855  10.602588  -2.771691
# 3      37.200975  -6.018291 -15.080594   9.141643   3.231752  -4.850000
# 4      13.414745 -23.272788  -7.771816  34.476214 -15.358442  12.999773
# ...          ...        ...        ...        ...        ...        ...
# 89995  26.796052  30.684325  12.904987  12.772483   6.841569   2.535513
# 89996  10.622823   5.836665   7.514305  -1.012314  -6.034214   6.938872
# 89997  44.858219  33.289573  15.510735  -4.239626  -6.390871 -15.229858
# 89998  -4.157606   7.856613   2.439329   6.916420 -14.584213   3.181416
# 89999  34.544072  22.852762   6.745608 -10.799295  -8.441946   9.483700
#
#               11         12  label
# 0       5.552410  -4.544200      0
# 1      -2.824660   9.077924      0
# 2      -1.992006  10.744815      0
# 3      -4.608707   8.939402      0
# 4      14.267405  -8.601142      0
# ...          ...        ...    ...
# 89995  -2.041178 -13.075402      8
# 89996  -0.135282  -2.873483      8
# 89997 -13.748360  -9.639236      8
# 89998  -2.542657  -3.054895      8
# 89999   3.371036  -2.706127      8
#
# [90000 rows x 15 columns]

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"



import torch
from torch.utils.data import Dataset, DataLoader
import pandas as pd

class CustomDataset(Dataset):
    def __init__(self, dataframe):
        self.data = dataframe.iloc[:, :-1].values  # 마지막 열을 제외한 데이터
        self.labels = dataframe.iloc[:, -1].values  # 마지막 열을 라벨 데이터로 사용

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = {'data': torch.tensor(self.data[idx], dtype=torch.float32),
                  'label': torch.tensor(self.labels[idx], dtype=torch.long)}
        return sample

# %%
train_dataset_pca = CustomDataset(train_merge_pca)
train_loader_pca = DataLoader(train_dataset_pca, batch_size=64, shuffle=True, drop_last=True)

test_dataset_pca = CustomDataset(test_merge_pca)
test_loader_pca = DataLoader(test_dataset_pca, batch_size=64, shuffle=False, drop_last=True)

# %%
import torch.nn as nn
import torch.optim as optim
from swin_transformer import SwinTimeSeriesTransformer 
import torch

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = SwinTimeSeriesTransformer(
    input_dim=1,
    seq_len=14,  # Now divisible by patch_size
    patch_size=2,  # Adjusted patch size
    num_classes=9,
    dim=64,
    depth=6,
    num_heads=8,
    window_size=3, 
    mlp_ratio=4.0,
    dropout=0.1
    
)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

from sklearn.metrics import f1_score, classification_report
import numpy as np
from tqdm.notebook import trange

valid_loss_min = np.inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader_pca)
valid_loss = np.inf  # train acc
f1_ = 0  # val f1
epoch_in = trange(10, desc='training')
best_acc=0

for epoch in epoch_in:
    model.to(device)
    model.train()
    running_loss = 0.0
    correct = 0
    total=0
    
    preds_ = []
    targets_ = []

    for batch_idx, train_dict in enumerate(train_loader_pca):
        print(f"Batch {batch_idx}, data shape: {train_dict['data'].shape}")

        seq_len = 14

        inputs = train_dict['data'].to(device).float()
        inputs = inputs.reshape(inputs.size(0), seq_len, 1)
        labels = train_dict['label'].to(device).long()

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==labels).item()
        total += labels.size(0)
        # if (batch_idx) % 1000 == 0:
        #     print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
        #            .format(epoch, n_epochs, batch_idx, total_step, loss.item()))

    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain loss: {np.mean(train_loss):.4f}, train acc: {(100 * correct / total):.4f}')

    
    batch_loss = 0
    total_t = 0
    correct_t = 0

preds_ = []
targets_ = []

with torch.no_grad():
    model.to(device)
    model.eval()
    for test_dict in test_loader_pca:  # You might want to use a validation loader here
        data_t = test_dict['data'].to(device).float()
        inputs = data_t.reshape(data_t.size(0), seq_len, 1)  # Reshaping to match input_dim (1)

        target_t = test_dict['label'].to(device).long()

        outputs_t = model(inputs)  # Pass the reshaped inputs

        pred = outputs_t.argmax(dim=1).to(device)
        preds_.append(pred)  # Append tensors to list
        targets_.append(target_t)  # Append tensors to list

        loss_t = criterion(outputs_t, target_t)
        batch_loss += loss_t.item()
        _, pred_t = torch.max(outputs_t, dim=1)
        correct_t += torch.sum(pred_t == target_t).item()
        total_t += target_t.size(0)

    # Concatenate all predictions and targets after the loop
    preds_ = torch.cat(preds_).detach().cpu().numpy()
    targets_ = torch.cat(targets_).detach().cpu().numpy()

    f1score = f1_score(targets_, preds_, average='macro')
    if best_acc < f1score:
        best_acc = f1score
        with open("0120_iotid_swin_transformer.txt", "a") as text_file:
            print('epoch=====', epoch, file=text_file)
            print(classification_report(targets_, preds_, digits=4), file=text_file)
        torch.save(model, f'0120_iotid_swin_transformer.pt')
    epoch_in.set_postfix_str(f"epoch = {epoch},  f1_score = {f1score}, best_f1 = {best_acc}")
# Out:
# Using device: cuda
# training:   0%|          | 0/1 [00:00<?, ?it/s]
# Batch 0, data shape: torch.Size([64, 14])
# Batch 1, data shape: torch.Size([64, 14])
# Batch 2, data shape: torch.Size([64, 14])
# Batch 3, data shape: torch.Size([64, 14])
# Batch 4, data shape: torch.Size([64, 14])
# Batch 5, data shape: torch.Size([64, 14])
# Batch 6, data shape: torch.Size([64, 14])
# Batch 7, data shape: torch.Size([64, 14])
# Batch 8, data shape: torch.Size([64, 14])
# Batch 9, data shape: torch.Size([64, 14])
# Batch 10, data shape: torch.Size([64, 14])
# Batch 11, data shape: torch.Size([64, 14])
# Batch 12, data shape: torch.Size([64, 14])
# Batch 13, data shape: torch.Size([64, 14])
# Batch 14, data shape: torch.Size([64, 14])
# Batch 15, data shape: torch.Size([64, 14])
# Batch 16, data shape: torch.Size([64, 14])
# Batch 17, data shape: torch.Size([64, 14])
# Batch 18, data shape: torch.Size([64, 14])
# Batch 19, data shape: torch.Size([64, 14])
# Batch 20, data shape: torch.Size([64, 14])
# Batch 21, data shape: torch.Size([64, 14])
# Batch 22, data shape: torch.Size([64, 14])
# Batch 23, data shape: torch.Size([64, 14])
# Batch 24, data shape: torch.Size([64, 14])
# Batch 25, data shape: torch.Size([64, 14])
# Batch 26, data shape: torch.Size([64, 14])
# Batch 27, data shape: torch.Size([64, 14])
# Batch 28, data shape: torch.Size([64, 14])
# Batch 29, data shape: torch.Size([64, 14])
# Batch 30, data shape: torch.Size([64, 14])
# Batch 31, data shape: torch.Size([64, 14])
# Batch 32, data shape: torch.Size([64, 14])
# Batch 33, data shape: torch.Size([64, 14])
# Batch 34, data shape: torch.Size([64, 14])
# Batch 35, data shape: torch.Size([64, 14])
# Batch 36, data shape: torch.Size([64, 14])
# Batch 37, data shape: torch.Size([64, 14])
# Batch 38, data shape: torch.Size([64, 14])
# Batch 39, data shape: torch.Size([64, 14])
# Batch 40, data shape: torch.Size([64, 14])
# Batch 41, data shape: torch.Size([64, 14])
# Batch 42, data shape: torch.Size([64, 14])
# Batch 43, data shape: torch.Size([64, 14])
# Batch 44, data shape: torch.Size([64, 14])
# Batch 45, data shape: torch.Size([64, 14])
# Batch 46, data shape: torch.Size([64, 14])
# Batch 47, data shape: torch.Size([64, 14])
# Batch 48, data shape: torch.Size([64, 14])
# Batch 49, data shape: torch.Size([64, 14])
# Batch 50, data shape: torch.Size([64, 14])
# Batch 51, data shape: torch.Size([64, 14])
# Batch 52, data shape: torch.Size([64, 14])
# Batch 53, data shape: torch.Size([64, 14])
# Batch 54, data shape: torch.Size([64, 14])
# Batch 55, data shape: torch.Size([64, 14])
# Batch 56, data shape: torch.Size([64, 14])
# Batch 57, data shape: torch.Size([64, 14])
# Batch 58, data shape: torch.Size([64, 14])
# Batch 59, data shape: torch.Size([64, 14])
# Batch 60, data shape: torch.Size([64, 14])
# Batch 61, data shape: torch.Size([64, 14])
# Batch 62, data shape: torch.Size([64, 14])
# Batch 63, data shape: torch.Size([64, 14])
# Batch 64, data shape: torch.Size([64, 14])
# Batch 65, data shape: torch.Size([64, 14])
# Batch 66, data shape: torch.Size([64, 14])
# Batch 67, data shape: torch.Size([64, 14])
# Batch 68, data shape: torch.Size([64, 14])
# Batch 69, data shape: torch.Size([64, 14])
# Batch 70, data shape: torch.Size([64, 14])
# Batch 71, data shape: torch.Size([64, 14])
# Batch 72, data shape: torch.Size([64, 14])
# Batch 73, data shape: torch.Size([64, 14])
# Batch 74, data shape: torch.Size([64, 14])
# Batch 75, data shape: torch.Size([64, 14])
# Batch 76, data shape: torch.Size([64, 14])
# Batch 77, data shape: torch.Size([64, 14])
# Batch 78, data shape: torch.Size([64, 14])
# Batch 79, data shape: torch.Size([64, 14])
# Batch 80, data shape: torch.Size([64, 14])
# Batch 81, data shape: torch.Size([64, 14])
# Batch 82, data shape: torch.Size([64, 14])
# Batch 83, data shape: torch.Size([64, 14])
# Batch 84, data shape: torch.Size([64, 14])
# Batch 85, data shape: torch.Size([64, 14])
# Batch 86, data shape: torch.Size([64, 14])
# Batch 87, data shape: torch.Size([64, 14])
# Batch 88, data shape: torch.Size([64, 14])
# Batch 89, data shape: torch.Size([64, 14])
# Batch 90, data shape: torch.Size([64, 14])
# Batch 91, data shape: torch.Size([64, 14])
# Batch 92, data shape: torch.Size([64, 14])
# Batch 93, data shape: torch.Size([64, 14])
# Batch 94, data shape: torch.Size([64, 14])
# Batch 95, data shape: torch.Size([64, 14])
# Batch 96, data shape: torch.Size([64, 14])
# Batch 97, data shape: torch.Size([64, 14])
# Batch 98, data shape: torch.Size([64, 14])
# Batch 99, data shape: torch.Size([64, 14])
# Batch 100, data shape: torch.Size([64, 14])
# Batch 101, data shape: torch.Size([64, 14])
# Batch 102, data shape: torch.Size([64, 14])
# Batch 103, data shape: torch.Size([64, 14])
# Batch 104, data shape: torch.Size([64, 14])
# Batch 105, data shape: torch.Size([64, 14])
# Batch 106, data shape: torch.Size([64, 14])
# Batch 107, data shape: torch.Size([64, 14])
# Batch 108, data shape: torch.Size([64, 14])
# Batch 109, data shape: torch.Size([64, 14])
# Batch 110, data shape: torch.Size([64, 14])
# Batch 111, data shape: torch.Size([64, 14])
# Batch 112, data shape: torch.Size([64, 14])
# Batch 113, data shape: torch.Size([64, 14])
# Batch 114, data shape: torch.Size([64, 14])
# Batch 115, data shape: torch.Size([64, 14])
# Batch 116, data shape: torch.Size([64, 14])
# Batch 117, data shape: torch.Size([64, 14])
# Batch 118, data shape: torch.Size([64, 14])
# Batch 119, data shape: torch.Size([64, 14])
# Batch 120, data shape: torch.Size([64, 14])
# Batch 121, data shape: torch.Size([64, 14])
# Batch 122, data shape: torch.Size([64, 14])
# Batch 123, data shape: torch.Size([64, 14])
# Batch 124, data shape: torch.Size([64, 14])
# Batch 125, data shape: torch.Size([64, 14])
# Batch 126, data shape: torch.Size([64, 14])
# Batch 127, data shape: torch.Size([64, 14])
# Batch 128, data shape: torch.Size([64, 14])
# Batch 129, data shape: torch.Size([64, 14])
# Batch 130, data shape: torch.Size([64, 14])
# Batch 131, data shape: torch.Size([64, 14])
# Batch 132, data shape: torch.Size([64, 14])
# Batch 133, data shape: torch.Size([64, 14])
# Batch 134, data shape: torch.Size([64, 14])
# Batch 135, data shape: torch.Size([64, 14])
# Batch 136, data shape: torch.Size([64, 14])
# Batch 137, data shape: torch.Size([64, 14])
# Batch 138, data shape: torch.Size([64, 14])
# Batch 139, data shape: torch.Size([64, 14])
# Batch 140, data shape: torch.Size([64, 14])
# Batch 141, data shape: torch.Size([64, 14])
# Batch 142, data shape: torch.Size([64, 14])
# Batch 143, data shape: torch.Size([64, 14])
# Batch 144, data shape: torch.Size([64, 14])
# Batch 145, data shape: torch.Size([64, 14])
# Batch 146, data shape: torch.Size([64, 14])
# Batch 147, data shape: torch.Size([64, 14])
# Batch 148, data shape: torch.Size([64, 14])
# Batch 149, data shape: torch.Size([64, 14])
# Batch 150, data shape: torch.Size([64, 14])
# Batch 151, data shape: torch.Size([64, 14])
# Batch 152, data shape: torch.Size([64, 14])
# Batch 153, data shape: torch.Size([64, 14])
# Batch 154, data shape: torch.Size([64, 14])
# Batch 155, data shape: torch.Size([64, 14])
# Batch 156, data shape: torch.Size([64, 14])
# Batch 157, data shape: torch.Size([64, 14])
# Batch 158, data shape: torch.Size([64, 14])
# Batch 159, data shape: torch.Size([64, 14])
# Batch 160, data shape: torch.Size([64, 14])
# Batch 161, data shape: torch.Size([64, 14])
# Batch 162, data shape: torch.Size([64, 14])
# Batch 163, data shape: torch.Size([64, 14])
# Batch 164, data shape: torch.Size([64, 14])
# Batch 165, data shape: torch.Size([64, 14])
# Batch 166, data shape: torch.Size([64, 14])
# Batch 167, data shape: torch.Size([64, 14])
# Batch 168, data shape: torch.Size([64, 14])
# Batch 169, data shape: torch.Size([64, 14])
# Batch 170, data shape: torch.Size([64, 14])
# Batch 171, data shape: torch.Size([64, 14])
# Batch 172, data shape: torch.Size([64, 14])
# Batch 173, data shape: torch.Size([64, 14])
# Batch 174, data shape: torch.Size([64, 14])
# Batch 175, data shape: torch.Size([64, 14])
# Batch 176, data shape: torch.Size([64, 14])
# Batch 177, data shape: torch.Size([64, 14])
# Batch 178, data shape: torch.Size([64, 14])
# Batch 179, data shape: torch.Size([64, 14])
# Batch 180, data shape: torch.Size([64, 14])
# Batch 181, data shape: torch.Size([64, 14])
# Batch 182, data shape: torch.Size([64, 14])
# Batch 183, data shape: torch.Size([64, 14])
# Batch 184, data shape: torch.Size([64, 14])
# Batch 185, data shape: torch.Size([64, 14])
# Batch 186, data shape: torch.Size([64, 14])
# Batch 187, data shape: torch.Size([64, 14])
# Batch 188, data shape: torch.Size([64, 14])
# Batch 189, data shape: torch.Size([64, 14])
# Batch 190, data shape: torch.Size([64, 14])
# Batch 191, data shape: torch.Size([64, 14])
# Batch 192, data shape: torch.Size([64, 14])
# Batch 193, data shape: torch.Size([64, 14])
# Batch 194, data shape: torch.Size([64, 14])
# Batch 195, data shape: torch.Size([64, 14])
# Batch 196, data shape: torch.Size([64, 14])
# Batch 197, data shape: torch.Size([64, 14])
# Batch 198, data shape: torch.Size([64, 14])
# Batch 199, data shape: torch.Size([64, 14])
# Batch 200, data shape: torch.Size([64, 14])
# Batch 201, data shape: torch.Size([64, 14])
# Batch 202, data shape: torch.Size([64, 14])
# Batch 203, data shape: torch.Size([64, 14])
# Batch 204, data shape: torch.Size([64, 14])
# Batch 205, data shape: torch.Size([64, 14])
# Batch 206, data shape: torch.Size([64, 14])
# Batch 207, data shape: torch.Size([64, 14])
# Batch 208, data shape: torch.Size([64, 14])
# Batch 209, data shape: torch.Size([64, 14])
# Batch 210, data shape: torch.Size([64, 14])
# Batch 211, data shape: torch.Size([64, 14])
# Batch 212, data shape: torch.Size([64, 14])
# Batch 213, data shape: torch.Size([64, 14])
# Batch 214, data shape: torch.Size([64, 14])
# Batch 215, data shape: torch.Size([64, 14])
# Batch 216, data shape: torch.Size([64, 14])
# Batch 217, data shape: torch.Size([64, 14])
# Batch 218, data shape: torch.Size([64, 14])
# Batch 219, data shape: torch.Size([64, 14])
# Batch 220, data shape: torch.Size([64, 14])
# Batch 221, data shape: torch.Size([64, 14])
# Batch 222, data shape: torch.Size([64, 14])
# Batch 223, data shape: torch.Size([64, 14])
# Batch 224, data shape: torch.Size([64, 14])
# Batch 225, data shape: torch.Size([64, 14])
# Batch 226, data shape: torch.Size([64, 14])
# Batch 227, data shape: torch.Size([64, 14])
# Batch 228, data shape: torch.Size([64, 14])
# Batch 229, data shape: torch.Size([64, 14])
# Batch 230, data shape: torch.Size([64, 14])
# Batch 231, data shape: torch.Size([64, 14])
# Batch 232, data shape: torch.Size([64, 14])
# Batch 233, data shape: torch.Size([64, 14])
# Batch 234, data shape: torch.Size([64, 14])
# Batch 235, data shape: torch.Size([64, 14])
# Batch 236, data shape: torch.Size([64, 14])
# Batch 237, data shape: torch.Size([64, 14])
# Batch 238, data shape: torch.Size([64, 14])
# Batch 239, data shape: torch.Size([64, 14])
# Batch 240, data shape: torch.Size([64, 14])
# Batch 241, data shape: torch.Size([64, 14])
# Batch 242, data shape: torch.Size([64, 14])
# Batch 243, data shape: torch.Size([64, 14])
# Batch 244, data shape: torch.Size([64, 14])
# Batch 245, data shape: torch.Size([64, 14])
# Batch 246, data shape: torch.Size([64, 14])
# Batch 247, data shape: torch.Size([64, 14])
# Batch 248, data shape: torch.Size([64, 14])
# Batch 249, data shape: torch.Size([64, 14])
# Batch 250, data shape: torch.Size([64, 14])
# Batch 251, data shape: torch.Size([64, 14])
# Batch 252, data shape: torch.Size([64, 14])
# Batch 253, data shape: torch.Size([64, 14])
# Batch 254, data shape: torch.Size([64, 14])
# Batch 255, data shape: torch.Size([64, 14])
# Batch 256, data shape: torch.Size([64, 14])
# Batch 257, data shape: torch.Size([64, 14])
# Batch 258, data shape: torch.Size([64, 14])
# Batch 259, data shape: torch.Size([64, 14])
# Batch 260, data shape: torch.Size([64, 14])
# Batch 261, data shape: torch.Size([64, 14])
# Batch 262, data shape: torch.Size([64, 14])
# Batch 263, data shape: torch.Size([64, 14])
# Batch 264, data shape: torch.Size([64, 14])
# Batch 265, data shape: torch.Size([64, 14])
# Batch 266, data shape: torch.Size([64, 14])
# Batch 267, data shape: torch.Size([64, 14])
# Batch 268, data shape: torch.Size([64, 14])
# Batch 269, data shape: torch.Size([64, 14])
# Batch 270, data shape: torch.Size([64, 14])
# Batch 271, data shape: torch.Size([64, 14])
# Batch 272, data shape: torch.Size([64, 14])
# Batch 273, data shape: torch.Size([64, 14])
# Batch 274, data shape: torch.Size([64, 14])
# Batch 275, data shape: torch.Size([64, 14])
# Batch 276, data shape: torch.Size([64, 14])
# Batch 277, data shape: torch.Size([64, 14])
# Batch 278, data shape: torch.Size([64, 14])
# Batch 279, data shape: torch.Size([64, 14])
# Batch 280, data shape: torch.Size([64, 14])
# Batch 281, data shape: torch.Size([64, 14])
# Batch 282, data shape: torch.Size([64, 14])
# Batch 283, data shape: torch.Size([64, 14])
# Batch 284, data shape: torch.Size([64, 14])
# Batch 285, data shape: torch.Size([64, 14])
# Batch 286, data shape: torch.Size([64, 14])
# Batch 287, data shape: torch.Size([64, 14])
# Batch 288, data shape: torch.Size([64, 14])
# Batch 289, data shape: torch.Size([64, 14])
# Batch 290, data shape: torch.Size([64, 14])
# Batch 291, data shape: torch.Size([64, 14])
# Batch 292, data shape: torch.Size([64, 14])
# Batch 293, data shape: torch.Size([64, 14])
# Batch 294, data shape: torch.Size([64, 14])
# Batch 295, data shape: torch.Size([64, 14])
# Batch 296, data shape: torch.Size([64, 14])
# Batch 297, data shape: torch.Size([64, 14])
# Batch 298, data shape: torch.Size([64, 14])
# Batch 299, data shape: torch.Size([64, 14])
# Batch 300, data shape: torch.Size([64, 14])
# Batch 301, data shape: torch.Size([64, 14])
# Batch 302, data shape: torch.Size([64, 14])
# Batch 303, data shape: torch.Size([64, 14])
# Batch 304, data shape: torch.Size([64, 14])
# Batch 305, data shape: torch.Size([64, 14])
# Batch 306, data shape: torch.Size([64, 14])
# Batch 307, data shape: torch.Size([64, 14])
# Batch 308, data shape: torch.Size([64, 14])
# Batch 309, data shape: torch.Size([64, 14])
# Batch 310, data shape: torch.Size([64, 14])
# Batch 311, data shape: torch.Size([64, 14])
# Batch 312, data shape: torch.Size([64, 14])
# Batch 313, data shape: torch.Size([64, 14])
# Batch 314, data shape: torch.Size([64, 14])
# Batch 315, data shape: torch.Size([64, 14])
# Batch 316, data shape: torch.Size([64, 14])
# Batch 317, data shape: torch.Size([64, 14])
# Batch 318, data shape: torch.Size([64, 14])
# Batch 319, data shape: torch.Size([64, 14])
# Batch 320, data shape: torch.Size([64, 14])
# Batch 321, data shape: torch.Size([64, 14])
# Batch 322, data shape: torch.Size([64, 14])
# Batch 323, data shape: torch.Size([64, 14])
# Batch 324, data shape: torch.Size([64, 14])
# Batch 325, data shape: torch.Size([64, 14])
# Batch 326, data shape: torch.Size([64, 14])
# Batch 327, data shape: torch.Size([64, 14])
# Batch 328, data shape: torch.Size([64, 14])
# Batch 329, data shape: torch.Size([64, 14])
# Batch 330, data shape: torch.Size([64, 14])
# Batch 331, data shape: torch.Size([64, 14])
# Batch 332, data shape: torch.Size([64, 14])
# Batch 333, data shape: torch.Size([64, 14])
# Batch 334, data shape: torch.Size([64, 14])
# Batch 335, data shape: torch.Size([64, 14])
# Batch 336, data shape: torch.Size([64, 14])
# Batch 337, data shape: torch.Size([64, 14])
# Batch 338, data shape: torch.Size([64, 14])
# Batch 339, data shape: torch.Size([64, 14])
# Batch 340, data shape: torch.Size([64, 14])
# Batch 341, data shape: torch.Size([64, 14])
# Batch 342, data shape: torch.Size([64, 14])
# Batch 343, data shape: torch.Size([64, 14])
# Batch 344, data shape: torch.Size([64, 14])
# Batch 345, data shape: torch.Size([64, 14])
# Batch 346, data shape: torch.Size([64, 14])
# Batch 347, data shape: torch.Size([64, 14])
# Batch 348, data shape: torch.Size([64, 14])
# Batch 349, data shape: torch.Size([64, 14])
# Batch 350, data shape: torch.Size([64, 14])
# Batch 351, data shape: torch.Size([64, 14])
# Batch 352, data shape: torch.Size([64, 14])
# Batch 353, data shape: torch.Size([64, 14])
# Batch 354, data shape: torch.Size([64, 14])
# Batch 491, data shape: torch.Size([64, 14])
# Batch 492, data shape: torch.Size([64, 14])
# Batch 493, data shape: torch.Size([64, 14])
# Batch 494, data shape: torch.Size([64, 14])
# Batch 495, data shape: torch.Size([64, 14])
# Batch 496, data shape: torch.Size([64, 14])
# Batch 497, data shape: torch.Size([64, 14])
# Batch 498, data shape: torch.Size([64, 14])
# Batch 499, data shape: torch.Size([64, 14])
# Batch 500, data shape: torch.Size([64, 14])
# Batch 501, data shape: torch.Size([64, 14])
# Batch 502, data shape: torch.Size([64, 14])
# Batch 503, data shape: torch.Size([64, 14])
# Batch 504, data shape: torch.Size([64, 14])
# Batch 505, data shape: torch.Size([64, 14])
# Batch 506, data shape: torch.Size([64, 14])
# Batch 507, data shape: torch.Size([64, 14])
# Batch 508, data shape: torch.Size([64, 14])
# Batch 509, data shape: torch.Size([64, 14])
# Batch 510, data shape: torch.Size([64, 14])
# Batch 511, data shape: torch.Size([64, 14])
# Batch 512, data shape: torch.Size([64, 14])
# Batch 513, data shape: torch.Size([64, 14])
# Batch 514, data shape: torch.Size([64, 14])
# Batch 515, data shape: torch.Size([64, 14])
# Batch 516, data shape: torch.Size([64, 14])
# Batch 517, data shape: torch.Size([64, 14])
# Batch 518, data shape: torch.Size([64, 14])
# Batch 519, data shape: torch.Size([64, 14])
# Batch 520, data shape: torch.Size([64, 14])
# Batch 521, data shape: torch.Size([64, 14])
# Batch 522, data shape: torch.Size([64, 14])
# Batch 523, data shape: torch.Size([64, 14])
# Batch 524, data shape: torch.Size([64, 14])
# Batch 525, data shape: torch.Size([64, 14])
# Batch 526, data shape: torch.Size([64, 14])
# Batch 527, data shape: torch.Size([64, 14])
# Batch 528, data shape: torch.Size([64, 14])
# Batch 529, data shape: torch.Size([64, 14])
# Batch 530, data shape: torch.Size([64, 14])
# Batch 531, data shape: torch.Size([64, 14])
# Batch 532, data shape: torch.Size([64, 14])
# Batch 533, data shape: torch.Size([64, 14])
# Batch 534, data shape: torch.Size([64, 14])
# Batch 535, data shape: torch.Size([64, 14])
# Batch 536, data shape: torch.Size([64, 14])
# Batch 537, data shape: torch.Size([64, 14])
# Batch 538, data shape: torch.Size([64, 14])
# Batch 539, data shape: torch.Size([64, 14])
# Batch 540, data shape: torch.Size([64, 14])
# Batch 541, data shape: torch.Size([64, 14])
# Batch 542, data shape: torch.Size([64, 14])
# Batch 543, data shape: torch.Size([64, 14])
# Batch 544, data shape: torch.Size([64, 14])
# Batch 545, data shape: torch.Size([64, 14])
# Batch 546, data shape: torch.Size([64, 14])
# Batch 547, data shape: torch.Size([64, 14])
# Batch 548, data shape: torch.Size([64, 14])
# Batch 549, data shape: torch.Size([64, 14])
# Batch 550, data shape: torch.Size([64, 14])
# Batch 551, data shape: torch.Size([64, 14])
# Batch 552, data shape: torch.Size([64, 14])
# Batch 553, data shape: torch.Size([64, 14])
# Batch 554, data shape: torch.Size([64, 14])
# Batch 555, data shape: torch.Size([64, 14])
# Batch 556, data shape: torch.Size([64, 14])
# Batch 557, data shape: torch.Size([64, 14])
# Batch 558, data shape: torch.Size([64, 14])
# Batch 559, data shape: torch.Size([64, 14])
# Batch 764, data shape: torch.Size([64, 14])
# Batch 765, data shape: torch.Size([64, 14])
# Batch 766, data shape: torch.Size([64, 14])
# Batch 767, data shape: torch.Size([64, 14])
# Batch 768, data shape: torch.Size([64, 14])
# Batch 769, data shape: torch.Size([64, 14])
# Batch 770, data shape: torch.Size([64, 14])
# Batch 771, data shape: torch.Size([64, 14])
# Batch 772, data shape: torch.Size([64, 14])
# Batch 773, data shape: torch.Size([64, 14])
# Batch 774, data shape: torch.Size([64, 14])
# Batch 775, data shape: torch.Size([64, 14])
# Batch 776, data shape: torch.Size([64, 14])
# Batch 777, data shape: torch.Size([64, 14])
# Batch 778, data shape: torch.Size([64, 14])
# Batch 779, data shape: torch.Size([64, 14])
# Batch 780, data shape: torch.Size([64, 14])
# Batch 781, data shape: torch.Size([64, 14])
# Batch 782, data shape: torch.Size([64, 14])
# Batch 783, data shape: torch.Size([64, 14])
# Batch 784, data shape: torch.Size([64, 14])
# Batch 785, data shape: torch.Size([64, 14])
# Batch 786, data shape: torch.Size([64, 14])
# Batch 787, data shape: torch.Size([64, 14])
# Batch 788, data shape: torch.Size([64, 14])
# Batch 789, data shape: torch.Size([64, 14])
# Batch 790, data shape: torch.Size([64, 14])
# Batch 791, data shape: torch.Size([64, 14])
# Batch 792, data shape: torch.Size([64, 14])
# Batch 793, data shape: torch.Size([64, 14])
# Batch 794, data shape: torch.Size([64, 14])
# Batch 795, data shape: torch.Size([64, 14])
# Batch 796, data shape: torch.Size([64, 14])
# Batch 797, data shape: torch.Size([64, 14])
# Batch 798, data shape: torch.Size([64, 14])
# Batch 799, data shape: torch.Size([64, 14])
# Batch 800, data shape: torch.Size([64, 14])
# Batch 801, data shape: torch.Size([64, 14])
# Batch 802, data shape: torch.Size([64, 14])
# Batch 803, data shape: torch.Size([64, 14])
# Batch 804, data shape: torch.Size([64, 14])
# Batch 805, data shape: torch.Size([64, 14])
# Batch 806, data shape: torch.Size([64, 14])
# Batch 807, data shape: torch.Size([64, 14])
# Batch 808, data shape: torch.Size([64, 14])
# Batch 809, data shape: torch.Size([64, 14])
# Batch 810, data shape: torch.Size([64, 14])
# Batch 811, data shape: torch.Size([64, 14])
# Batch 812, data shape: torch.Size([64, 14])
# Batch 813, data shape: torch.Size([64, 14])
# Batch 814, data shape: torch.Size([64, 14])
# Batch 815, data shape: torch.Size([64, 14])
# Batch 816, data shape: torch.Size([64, 14])
# Batch 817, data shape: torch.Size([64, 14])
# Batch 818, data shape: torch.Size([64, 14])
# Batch 819, data shape: torch.Size([64, 14])
# Batch 820, data shape: torch.Size([64, 14])
# Batch 821, data shape: torch.Size([64, 14])
# Batch 822, data shape: torch.Size([64, 14])
# Batch 823, data shape: torch.Size([64, 14])
# Batch 824, data shape: torch.Size([64, 14])
# Batch 825, data shape: torch.Size([64, 14])
# Batch 826, data shape: torch.Size([64, 14])
# Batch 827, data shape: torch.Size([64, 14])
# Batch 828, data shape: torch.Size([64, 14])
# Batch 829, data shape: torch.Size([64, 14])
# Batch 830, data shape: torch.Size([64, 14])
# Batch 831, data shape: torch.Size([64, 14])
# Batch 832, data shape: torch.Size([64, 14])
# Batch 901, data shape: torch.Size([64, 14])
# Batch 902, data shape: torch.Size([64, 14])
# Batch 903, data shape: torch.Size([64, 14])
# Batch 904, data shape: torch.Size([64, 14])
# Batch 905, data shape: torch.Size([64, 14])
# Batch 906, data shape: torch.Size([64, 14])
# Batch 907, data shape: torch.Size([64, 14])
# Batch 908, data shape: torch.Size([64, 14])
# Batch 909, data shape: torch.Size([64, 14])
# Batch 910, data shape: torch.Size([64, 14])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 64
#      60 labels = train_dict['label'].to(device).long()
#      62 optimizer.zero_grad()
# ---> 64 outputs = model(inputs)
#      65 loss = criterion(outputs, labels)
#      66 loss.backward()
#
# File c:\Users\addmin\anaconda3\envs\raypann\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\addmin\anaconda3\envs\raypann\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\addmin\Downloads\IoT_Network_swin_transformer\Model\IoTID20\swin_transformer.py:108, in SwinTimeSeriesTransformer.forward(self, x)
#     106 # Apply Swin Transformer blocks
#     107 for block in self.swin_blocks:
# --> 108     x = block(x)  # (batch_size, num_patches, dim)
#     110 # Global average pooling and classification
#     111 x = x.mean(dim=1)  # (batch_size, dim)
#
# File c:\Users\addmin\anaconda3\envs\raypann\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\addmin\anaconda3\envs\raypann\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\addmin\Downloads\IoT_Network_swin_transformer\Model\IoTID20\swin_transformer.py:64, in SwinBlock.forward(self, x)
#      61 x = self.attn(x) + x
#      63 # MLP
# ---> 64 x = self.norm2(x)
#      65 x = self.mlp(x) + x
#      66 return x
#
# File c:\Users\addmin\anaconda3\envs\raypann\Lib\site-packages\torch\nn\modules\module.py:1918, in Module.__getattr__(self, name)
#    1909         self._backward_pre_hooks = OrderedDict()
#    1911 # On the return type:
#    1912 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1913 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1916 # See full discussion on the problems with returning `Union` here
#    1917 # https://github.com/microsoft/pyright/issues/4213
# -> 1918 def __getattr__(self, name: str) -> Any:
#    1919     if "_parameters" in self.__dict__:
#    1920         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
import torch.nn as nn
import torch.optim as optim
from swin_transformer import SwinTimeSeriesTransformer 
import torch

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = SwinTimeSeriesTransformer(
    input_dim=1,
    seq_len=12,  # Now divisible by patch_size
    patch_size=3,  # Adjusted patch size
    num_classes=2,
    dim=64,
    depth=6,
    num_heads=8,
    window_size=3, 
    mlp_ratio=4.0,
    dropout=0.1
    
)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

from sklearn.metrics import f1_score, classification_report
import numpy as np
from tqdm.notebook import trange

valid_loss_min = np.inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader_pca)
valid_loss = np.inf  # train acc
f1_ = 0  # val f1
epoch_in = trange(100, desc='training')
best_acc=0

for epoch in epoch_in:
    model.to(device)
    model.train()
    running_loss = 0.0
    correct = 0
    total=0
    
    preds_ = []
    targets_ = []

    for batch_idx, train_dict in enumerate(train_loader_pca):
        print(f"Batch {batch_idx}, data shape: {train_dict['data'].shape}")

        seq_len = 12

        inputs = train_dict['data'].to(device).float()
        inputs = inputs.reshape(64,12,1)
        labels = train_dict['label'].to(device).long()
        print(f"Batch {batch_idx}, Inputs shape: {inputs.shape}, Labels: {labels}")

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==labels).item()
        total += labels.size(0)
        # if (batch_idx) % 1000 == 0:
        #     print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
        #            .format(epoch, n_epochs, batch_idx, total_step, loss.item()))

    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain loss: {np.mean(train_loss):.4f}, train acc: {(100 * correct / total):.4f}')

    
    batch_loss = 0
    total_t = 0
    correct_t = 0

preds_ = []
targets_ = []

with torch.no_grad():
    model.to(device)
    model.eval()
    for test_dict in test_loader_pca:  # You might want to use a validation loader here
        data_t = test_dict['data'].to(device).float()
        data_t = data_t.reshape(64,12,1)  # Reshaping to match input_dim (1)

        target_t = test_dict['label'].to(device).long()

        outputs_t = model(data_t)  # Pass the reshaped inputs

        pred = outputs_t.argmax(dim=1).to(device)
        preds_.append(pred)  # Append tensors to list
        targets_.append(target_t)  # Append tensors to list

        loss_t = criterion(outputs_t, target_t)
        batch_loss += loss_t.item()
        _, pred_t = torch.max(outputs_t, dim=1)
        correct_t += torch.sum(pred_t == target_t).item()
        total_t += target_t.size(0)

    # Concatenate all predictions and targets after the loop
    preds_ = torch.cat(preds_).detach().cpu().numpy()
    targets_ = torch.cat(targets_).detach().cpu().numpy()

    f1score = f1_score(targets_, preds_, average='macro')
    if best_acc < f1score:
        best_acc = f1score
        with open("0117_iotid_swin_transformer_mfcc.txt", "a") as text_file:
            print('epoch=====', epoch, file=text_file)
            print(classification_report(targets_, preds_, digits=4), file=text_file)
        torch.save(model, f'0117_iotid_swin_transformer_mfcc.pt')
    epoch_in.set_postfix_str(f"epoch = {epoch},  f1_score = {f1score}, best_f1 = {best_acc}")

# %% [markdown]
# # Mel spectrogram 이미지 생성

# %% [markdown]
# # Test dataset

# %%
import os

# 이미지 저장 디렉토리 생성
output_directory_n = './melspec/test/normal'
os.makedirs(output_directory_n, exist_ok=True)

output_directory_1= './melspec/test/label1'
os.makedirs(output_directory_1, exist_ok=True)

output_directory_2= './melspec/test/label2'
os.makedirs(output_directory_2, exist_ok=True)

output_directory_3= './melspec/test/label3'
os.makedirs(output_directory_3, exist_ok=True)

output_directory_4= './melspec/test/label4'
os.makedirs(output_directory_4, exist_ok=True)

output_directory_5= './melspec/test/label5'
os.makedirs(output_directory_5, exist_ok=True)

output_directory_6= './melspec/test/label6'
os.makedirs(output_directory_6, exist_ok=True)

output_directory_7= './melspec/test/label7'
os.makedirs(output_directory_7, exist_ok=True)

output_directory_8= './melspec/test/label8'
os.makedirs(output_directory_8, exist_ok=True)

# %%
import os

# 이미지 저장 디렉토리 생성
output_directory_n = './melspec/train/normal'
#os.makedirs(output_directory_n, exist_ok=True)

output_directory_1= './melspec/train/label1'
#os.makedirs(output_directory_1, exist_ok=True)

output_directory_2= './melspec/train/label2'
#os.makedirs(output_directory_2, exist_ok=True)

output_directory_3= './melspec/train/label3'
#os.makedirs(output_directory_3, exist_ok=True)

output_directory_4= './melspec/train/label4'
#os.makedirs(output_directory_4, exist_ok=True)

output_directory_5= './melspec/train/label5'
#os.makedirs(output_directory_5, exist_ok=True)

output_directory_6= './melspec/train/label6'
#os.makedirs(output_directory_6, exist_ok=True)

output_directory_7= './melspec/train/label7'
#os.makedirs(output_directory_7, exist_ok=True)

output_directory_8= './melspec/train/label8'
#os.makedirs(output_directory_8, exist_ok=True)

# %%
import pandas as pd 

train_df = pd.read_csv('./iotid20_train_pca+mfcc.csv')

# %%
zero_label_rows = train_df[train_df['label'] == 0] # 정상데이터 
one_label_rows = train_df[train_df['label'] == 1] # 비정상 데이터 
two_label_rows = train_df[train_df['label'] == 2] # 비정상 데이터 
three_label_rows = train_df[train_df['label'] == 3] # 비정상 데이터 
four_label_rows = train_df[train_df['label'] == 4] # 비정상 데이터 
five_label_rows = train_df[train_df['label'] == 5] # 비정상 데이터 
six_label_rows = train_df[train_df['label'] == 6] # 비정상 데이터 
sev_label_rows = train_df[train_df['label'] == 7] # 비정상 데이터 
eig_label_rows = train_df[train_df['label'] == 8] # 비정상 데이터

# %%
train__sample_val_normal = zero_label_rows.iloc[:,:-1].values
test_1 = one_label_rows.iloc[:,:-1].values
test_2 = two_label_rows.iloc[:,:-1].values
test_3 = three_label_rows.iloc[:,:-1].values
test_4 = four_label_rows.iloc[:,:-1].values
test_5 = five_label_rows.iloc[:,:-1].values
test_6 = six_label_rows.iloc[:,:-1].values
test_7 = sev_label_rows.iloc[:,:-1].values
test_8 = eig_label_rows.iloc[:,:-1].values

# %%
import librosa 
import librosa.display 
import matplotlib.pyplot as plt 
import tqdm 
import os
import numpy as np

SAMPLE_RATE = 1365 
DURATION = 0.75 
win_length = int(1365/40)
n_fft = 1024
hop_length = 4 
n_mels = 40

def run (df, path):
    for i in tqdm.tqdm(range(df.shape[0])):
        data = df[i:i+1, :].reshape(-1)
        S = librosa.feature.melspectrogram(y=data, n_mels=n_mels, n_fft=n_fft, hop_length=hop_length)
        mel_spec_db = librosa.power_to_db(S, ref=np.max)

        # 플롯 생성
        plt.figure(figsize=(10, 4))  # 이미지 크기 조절
        librosa.display.specshow(mel_spec_db, x_axis='time', y_axis='mel',\
            sr=SAMPLE_RATE, hop_length=hop_length, cmap='viridis')

        # 눈금 및 레이블 제거
        plt.axis('off')

        # 이미지 저장
        plt.savefig(f'{path}/image_{i}.png', bbox_inches='tight', pad_inches=0)

        # 플롯 닫기 (메모리 누수 방지)
        plt.close()

run(train__sample_val_normal, output_directory_n)
run(test_1, output_directory_1)
run(test_2, output_directory_2)
run(test_3, output_directory_3)
run(test_4, output_directory_4)
run(test_5, output_directory_5)
run(test_6, output_directory_6)
run(test_7, output_directory_7)
run(test_8, output_directory_8)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]c:\Users\user\anaconda3\envs\mintorch1221\lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=12
#   warnings.warn(
# 100%|██████████| 1000/1000 [00:57<00:00, 17.34it/s]
# 100%|██████████| 1000/1000 [00:56<00:00, 17.70it/s]
# 100%|██████████| 1000/1000 [01:04<00:00, 15.62it/s]
# 100%|██████████| 1000/1000 [01:06<00:00, 14.95it/s]
# 100%|██████████| 1000/1000 [01:10<00:00, 14.23it/s]
# 100%|██████████| 1000/1000 [01:14<00:00, 13.41it/s]
# 100%|██████████| 1000/1000 [01:20<00:00, 12.49it/s]
# 100%|██████████| 1000/1000 [01:22<00:00, 12.14it/s]
# 100%|██████████| 1000/1000 [01:34<00:00, 10.59it/s]
